# %% [markdown]
# # seaborn: statistical data visualization
#
# See [seaborn: statistical data visualization](https://seaborn.pydata.org/) for the home page
#
# See [Seaborn tutorial](https://seaborn.pydata.org/tutorial.html)
#
# See [Controlling figure aesthetics](https://seaborn.pydata.org/tutorial/aesthetics.html) for these plots

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, "aesthetics")))

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sns.set()
sinplot()
plt.show()

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data);
plt.show()

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10, trim=True);
plt.show()
